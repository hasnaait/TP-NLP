# %%
import spacy
from spacy.lang.ar import Arabic


nlp = Arabic()


text = u'ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي و هي بدايات الجبر، و من المهم فهم كيف كانت هذه الفكرة الجديدة مهمة، فقد كانت خطوة ثورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة، الجبر كان نظرية موحدة تتيح الأعداد الكسرية و الأعداد اللا كسرية، و المقادير الهندسية و غيرها، أن تتعامل على أنها أجسام جبرية، و أعطت الرياضيات ككل مسارا جديدا للتطور بمفهوم أوسع بكثير من الذي كان موجودا من قبل، و قدم وسيلة للتنمية في هذا الموضوع مستقبلا و جانب آخر مهم لإدخال أفكار الجبر و هو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل'



doc = nlp(text)

token_list = []
for w in doc:
           token_list.append(w.text)
print (token_list)

lemmas = [[token.text,token.lemma_] for token in doc]
print(lemmas)

print("\n")

filtered_sent=[]

for word in doc:
           if word.is_stop==False and word.text.isalpha()==True:
                      filtered_sent.append(word)
print(filtered_sent)

post_tag=[]

for post in doc:
           post_tag.append([post.text,post.pos_])
print (post_tag)
# Out:
# ['ربما', 'كانت', 'أحد', 'أهم', 'التطورات', 'التي', 'قامت', 'بها', 'الرياضيات', 'العربية', 'التي', 'بدأت', 'في', 'هذا', 'الوقت', 'بعمل', 'الخوارزمي', 'و', 'هي', 'بدايات', 'الجبر', '،', 'و', 'من', 'المهم', 'فهم', 'كيف', 'كانت', 'هذه', 'الفكرة', 'الجديدة', 'مهمة', '،', 'فقد', 'كانت', 'خطوة', 'ثورية', 'بعيدا', 'عن', 'المفهوم', 'اليوناني', 'للرياضيات', 'التي', 'هي', 'في', 'جوهرها', 'هندسة', '،', 'الجبر', 'كان', 'نظرية', 'موحدة', 'تتيح', 'الأعداد', 'الكسرية', 'و', 'الأعداد', 'اللا', 'كسرية', '،', 'و', 'المقادير', 'الهندسية', 'و', 'غيرها', '،', 'أن', 'تتعامل', 'على', 'أنها', 'أجسام', 'جبرية', '،', 'و', 'أعطت', 'الرياضيات', 'ككل', 'مسارا', 'جديدا', 'للتطور', 'بمفهوم', 'أوسع', 'بكثير', 'من', 'الذي', 'كان', 'موجودا', 'من', 'قبل', '،', 'و', 'قدم', 'وسيلة', 'للتنمية', 'في', 'هذا', 'الموضوع', 'مستقبلا', 'و', 'جانب', 'آخر', 'مهم', 'لإدخال', 'أفكار', 'الجبر', 'و', 'هو', 'أنه', 'سمح', 'بتطبيق', 'الرياضيات', 'على', 'نفسها', 'بطريقة', 'لم', 'تحدث', 'من', 'قبل']
# [['ربما', 'ربما'], ['كانت', 'كانت'], ['أحد', 'أحد'], ['أهم', 'أهم'], ['التطورات', 'التطورات'], ['التي', 'التي'], ['قامت', 'قامت'], ['بها', 'بها'], ['الرياضيات', 'الرياضيات'], ['العربية', 'العربية'], ['التي', 'التي'], ['بدأت', 'بدأت'], ['في', 'في'], ['هذا', 'هذا'], ['الوقت', 'الوقت'], ['بعمل', 'بعمل'], ['الخوارزمي', 'الخوارزمي'], ['و', 'و'], ['هي', 'هي'], ['بدايات', 'بدايات'], ['الجبر', 'الجبر'], ['،', '،'], ['و', 'و'], ['من', 'من'], ['المهم', 'المهم'], ['فهم', 'فهم'], ['كيف', 'كيف'], ['كانت', 'كانت'], ['هذه', 'هذه'], ['الفكرة', 'الفكرة'], ['الجديدة', 'الجديدة'], ['مهمة', 'مهمة'], ['،', '،'], ['فقد', 'فقد'], ['كانت', 'كانت'], ['خطوة', 'خطوة'], ['ثورية', 'ثورية'], ['بعيدا', 'بعيدا'], ['عن', 'عن'], ['المفهوم', 'المفهوم'], ['اليوناني', 'اليوناني'], ['للرياضيات', 'للرياضيات'], ['التي', 'التي'], ['هي', 'هي'], ['في', 'في'], ['جوهرها', 'جوهرها'], ['هندسة', 'هندسة'], ['،', '،'], ['الجبر', 'الجبر'], ['كان', 'كان'], ['نظرية', 'نظرية'], ['موحدة', 'موحدة'], ['تتيح', 'تتيح'], ['الأعداد', 'الأعداد'], ['الكسرية', 'الكسرية'], ['و', 'و'], ['الأعداد', 'الأعداد'], ['اللا', 'اللا'], ['كسرية', 'كسرية'], ['،', '،'], ['و', 'و'], ['المقادير', 'المقادير'], ['الهندسية', 'الهندسية'], ['و', 'و'], ['غيرها', 'غيرها'], ['،', '،'], ['أن', 'أن'], ['تتعامل', 'تتعامل'], ['على', 'على'], ['أنها', 'أنها'], ['أجسام', 'أجسام'], ['جبرية', 'جبرية'], ['،', '،'], ['و', 'و'], ['أعطت', 'أعطت'], ['الرياضيات', 'الرياضيات'], ['ككل', 'ككل'], ['مسارا', 'مسارا'], ['جديدا', 'جديدا'], ['للتطور', 'للتطور'], ['بمفهوم', 'بمفهوم'], ['أوسع', 'أوسع'], ['بكثير', 'بكثير'], ['من', 'من'], ['الذي', 'الذي'], ['كان', 'كان'], ['موجودا', 'موجودا'], ['من', 'من'], ['قبل', 'قبل'], ['،', '،'], ['و', 'و'], ['قدم', 'قدم'], ['وسيلة', 'وسيلة'], ['للتنمية', 'للتنمية'], ['في', 'في'], ['هذا', 'هذا'], ['الموضوع', 'الموضوع'], ['مستقبلا', 'مستقبلا'], ['و', 'و'], ['جانب', 'جانب'], ['آخر', 'آخر'], ['مهم', 'مهم'], ['لإدخال', 'لإدخال'], ['أفكار', 'أفكار'], ['الجبر', 'الجبر'], ['و', 'و'], ['هو', 'هو'], ['أنه', 'أنه'], ['سمح', 'سمح'], ['بتطبيق', 'بتطبيق'], ['الرياضيات', 'الرياضيات'], ['على', 'على'], ['نفسها', 'نفسها'], ['بطريقة', 'بطريقة'], ['لم', 'لم'], ['تحدث', 'تحدث'], ['من', 'من'], ['قبل', 'قبل']]
